# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
df=pd.read_csv('laptopPrice.csv')

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    str
#  1   processor_brand    823 non-null    str
#  2   processor_name     823 non-null    str
#  3   processor_gnrtn    823 non-null    str
#  4   ram_gb             823 non-null    str
#  5   ram_type           823 non-null    str
#  6   ssd                823 non-null    str
#  7   hdd                823 non-null    str
#  8   os                 823 non-null    str
#  9   os_bit             823 non-null    str
#  10  graphic_card_gb    823 non-null    str
#  11  weight             823 non-null    str
#  12  warranty           823 non-null    str
#  13  Touchscreen        823 non-null    str
#  14  msoffice           823 non-null    str
#  15  Price              823 non-null    int64
#  16  rating             823 non-null    str
# ...

# %%
df.columns
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'Price', 'rating',
#        'Number of Ratings', 'Number of Reviews'],
#       dtype='str')

# %%
df.brand
# Out:
# 0        ASUS
# 1      Lenovo
# 2      Lenovo
# 3        ASUS
# 4        ASUS
#         ...
# 818      ASUS
# 819      ASUS
# 820      ASUS
# 821      ASUS
# 822    Lenovo
# Name: brand, Length: 823, dtype: str

# %%
df[['brand']]
# Out:
#       brand
# 0      ASUS
# 1    Lenovo
# 2    Lenovo
# 3      ASUS
# 4      ASUS
# ..      ...
# 818    ASUS
# 819    ASUS
# 820    ASUS
# 821    ASUS
# 822  Lenovo
#
# [823 rows x 1 columns]

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 818    False
# 819    False
# 820    False
# 821    False
# 822    False
# Length: 823, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(21)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull()
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0    False            False           False            False   False
# 1    False            False           False            False   False
# 2    False            False           False            False   False
# 3    False            False           False            False   False
# 4    False            False           False            False   False
# ..     ...              ...             ...              ...     ...
# 818  False            False           False            False   False
# 819  False            False           False            False   False
# 820  False            False           False            False   False
# 821  False            False           False            False   False
# 822  False            False           False            False   False
#
#      ram_type    ssd    hdd     os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
df.isnull()
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0    False            False           False            False   False
# 1    False            False           False            False   False
# 2    False            False           False            False   False
# 3    False            False           False            False   False
# 4    False            False           False            False   False
# ..     ...              ...             ...              ...     ...
# 818  False            False           False            False   False
# 819  False            False           False            False   False
# 820  False            False           False            False   False
# 821  False            False           False            False   False
# 822  False            False           False            False   False
#
#      ram_type    ssd    hdd     os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
df.isnull().sum()
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df['brand'].unique()
# Out:
# <StringArray>
# ['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE']
# Length: 8, dtype: str

# %%
df['brand'].nunique()
# Out:
# 8

# %%
df['brand'].value_counts()
# Out:
# brand
# ASUS      243
# DELL      149
# Lenovo    144
# HP        136
# acer       51
# MSI        50
# APPLE      23
# Avita       6
# Name: count, dtype: int64

# %%
df.drop(['weight'	,'warranty','processor_name',	'processor_gnrtn'	,'ram_gb',	'ram_type',	'ssd',	'hdd'],axis=1,inplace=True)

# %%
df
# Out:
#       brand processor_brand       os  os_bit graphic_card_gb Touchscreen  \
# 0      ASUS           Intel  Windows  64-bit            0 GB          No
# 1    Lenovo           Intel  Windows  64-bit            0 GB          No
# 2    Lenovo           Intel  Windows  64-bit            0 GB          No
# 3      ASUS           Intel  Windows  32-bit            2 GB          No
# 4      ASUS           Intel  Windows  64-bit            0 GB          No
# ..      ...             ...      ...     ...             ...         ...
# 818    ASUS             AMD  Windows  64-bit            0 GB          No
# 819    ASUS             AMD  Windows  64-bit            0 GB          No
# 820    ASUS             AMD  Windows  64-bit            4 GB          No
# 821    ASUS             AMD  Windows  64-bit            4 GB          No
# 822  Lenovo             AMD      DOS  64-bit            0 GB          No
#
#     msoffice   Price   rating  Number of Ratings  Number of Reviews
# ...

# %%
df.drop(['Touchscreen',	'msoffice','processor_brand',	'os'],axis=1,inplace=True)

# %%
df
# Out:
#       brand  os_bit graphic_card_gb   Price   rating  Number of Ratings  \
# 0      ASUS  64-bit            0 GB   34649  2 stars                  3
# 1    Lenovo  64-bit            0 GB   38999  3 stars                 65
# 2    Lenovo  64-bit            0 GB   39999  3 stars                  8
# 3      ASUS  32-bit            2 GB   69990  3 stars                  0
# 4      ASUS  64-bit            0 GB   26990  3 stars                  0
# ..      ...     ...             ...     ...      ...                ...
# 818    ASUS  64-bit            0 GB  135990  3 stars                  0
# 819    ASUS  64-bit            0 GB  144990  3 stars                  0
# 820    ASUS  64-bit            4 GB  149990  3 stars                  0
# 821    ASUS  64-bit            4 GB  142990  3 stars                  0
# 822  Lenovo  64-bit            0 GB   57490  4 stars                 18
#
#      Number of Reviews
# 0                    0
# 1                    5
# 2                    1
# ...

# %%
#encoding
df['brand'].unique()
# Out:
# <StringArray>
# ['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE']
# Length: 8, dtype: str

# %%
brand_dict={
    'ASUS':1, 'Lenovo':2, 'acer':3, 'Avita':4, 'HP':5, 'DELL':6, 'MSI':7, 'APPLE':8
    
}

# %%
df['brand']=df['brand'].map(brand_dict)

# %%
df
# Out:
#      brand  os_bit graphic_card_gb   Price   rating  Number of Ratings  \
# 0        1  64-bit            0 GB   34649  2 stars                  3
# 1        2  64-bit            0 GB   38999  3 stars                 65
# 2        2  64-bit            0 GB   39999  3 stars                  8
# 3        1  32-bit            2 GB   69990  3 stars                  0
# 4        1  64-bit            0 GB   26990  3 stars                  0
# ..     ...     ...             ...     ...      ...                ...
# 818      1  64-bit            0 GB  135990  3 stars                  0
# 819      1  64-bit            0 GB  144990  3 stars                  0
# 820      1  64-bit            4 GB  149990  3 stars                  0
# 821      1  64-bit            4 GB  142990  3 stars                  0
# 822      2  64-bit            0 GB   57490  4 stars                 18
#
#      Number of Reviews
# 0                    0
# 1                    5
# 2                    1
# ...

# %%
df['rating'].unique()
# Out:
# <StringArray>
# ['2 stars', '3 stars', '4 stars', '5 stars', '1 star']
# Length: 5, dtype: str

# %%
rating_dict={
    '2 stars':2, '3 stars':3, '4 stars':4, '5 stars':5, '1 star':1
}
df['rating']=df['rating'].map(rating_dict)

# %%
df
# Out:
#      brand  os_bit graphic_card_gb   Price  rating  Number of Ratings  \
# 0        1  64-bit            0 GB   34649       2                  3
# 1        2  64-bit            0 GB   38999       3                 65
# 2        2  64-bit            0 GB   39999       3                  8
# 3        1  32-bit            2 GB   69990       3                  0
# 4        1  64-bit            0 GB   26990       3                  0
# ..     ...     ...             ...     ...     ...                ...
# 818      1  64-bit            0 GB  135990       3                  0
# 819      1  64-bit            0 GB  144990       3                  0
# 820      1  64-bit            4 GB  149990       3                  0
# 821      1  64-bit            4 GB  142990       3                  0
# 822      2  64-bit            0 GB   57490       4                 18
#
#      Number of Reviews
# 0                    0
# 1                    5
# 2                    1
# 3                    0
# ...

# %%
df['os_bit'].unique()
# Out:
# <StringArray>
# ['64-bit', '32-bit']
# Length: 2, dtype: str

# %%
osbit_dict={
    '64-bit':64, '32-bit':32
}
df['os_bit']=df['os_bit'].map(osbit_dict)

# %%
df['graphic_card_gb'].unique()
# Out:
# <StringArray>
# ['0 GB', '2 GB', '4 GB', '6 GB', '8 GB']
# Length: 5, dtype: str

# %%
card_dict={
'0 GB':0, '2 GB':2, '4 GB':4, '6 GB':6, '8 GB':8
}
df['graphic_card_gb']=df['graphic_card_gb'].map(card_dict)

# %%
df
# Out:
#      brand  os_bit  graphic_card_gb   Price  rating  Number of Ratings  \
# 0        1      64                0   34649       2                  3
# 1        2      64                0   38999       3                 65
# 2        2      64                0   39999       3                  8
# 3        1      32                2   69990       3                  0
# 4        1      64                0   26990       3                  0
# ..     ...     ...              ...     ...     ...                ...
# 818      1      64                0  135990       3                  0
# 819      1      64                0  144990       3                  0
# 820      1      64                4  149990       3                  0
# 821      1      64                4  142990       3                  0
# 822      2      64                0   57490       4                 18
#
#      Number of Reviews
# 0                    0
# 1                    5
# 2                    1
# ...

# %%
x=df.drop('Price',axis=1)

# %%
x
# Out:
#      brand  os_bit  graphic_card_gb  rating  Number of Ratings  \
# 0        1      64                0       2                  3
# 1        2      64                0       3                 65
# 2        2      64                0       3                  8
# 3        1      32                2       3                  0
# 4        1      64                0       3                  0
# ..     ...     ...              ...     ...                ...
# 818      1      64                0       3                  0
# 819      1      64                0       3                  0
# 820      1      64                4       3                  0
# 821      1      64                4       3                  0
# 822      2      64                0       4                 18
#
#      Number of Reviews
# 0                    0
# 1                    5
# 2                    1
# 3                    0
# 4                    0
# ..                 ...
# 818                  0
# ...

# %%
y=df[['Price']]

# %%
y
# Out:
#       Price
# 0     34649
# 1     38999
# 2     39999
# 3     69990
# 4     26990
# ..      ...
# 818  135990
# 819  144990
# 820  149990
# 821  142990
# 822   57490
#
# [802 rows x 1 columns]

# %%
# df.to_csv('clean laptopPrice.csv')

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sklearn as sns

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train ,y_test =train_test_split(x , y , test_size=0.2, random_state= 42)

# %%
print(x_train.shape, x_test.shape , y_train.shape ,y_test.shape)
# Out:
# (641, 6) (161, 6) (641, 1) (161, 1)

# %%
x_train
# Out:
#      brand  os_bit  graphic_card_gb  rating  Number of Ratings  \
# 442      1      32                0       4               1188
# 598      1      32                6       3                  2
# 452      1      64                2       4                 33
# 696      6      64                0       3                  0
# 339      1      64                0       4                 35
# ..     ...     ...              ...     ...                ...
# 73       2      32                0       3                  3
# 108      6      64                0       4                 10
# 275      2      64                2       3                  0
# 445      1      64                0       3                  0
# 104      1      64                0       4               2058
#
#      Number of Reviews
# 442                127
# 598                  1
# 452                  4
# 696                  0
# 339                  6
# ..                 ...
# 73                   0
# ...

# %%
from sklearn.linear_model import LinearRegression
lr =LinearRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
x_test
# Out:
#      brand  os_bit  graphic_card_gb  rating  Number of Ratings  \
# 196      3      32                4       4              10966
# 299      1      32                0       4                 76
# 171      6      64                0       5                  7
# 537      5      64                6       4                 17
# 551      7      64                8       4                 14
# ..     ...     ...              ...     ...                ...
# 368      1      64                0       3                  0
# 361      5      64                0       5                  2
# 446      6      64                0       4                 47
# 767      2      64                4       3                  0
# 529      2      32                0       3                  0
#
#      Number of Reviews
# 196               1185
# 299                 14
# 171                  5
# 537                  4
# 551                  3
# ..                 ...
# 368                  0
# ...

# %%
pred =lr.predict(x_test)

# %%
lst=[[3,	32,	4,	4,	10966,	1185]]

# %%
lr.predict(lst)
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[45588.59030972]])

# %%
pred
# Out:
# array([[ 45588.59030972],
#        [ 56007.13623205],
#        [ 63802.61429059],
#        [129141.72155485],
#        [152680.72648553],
#        [103649.86039668],
#        [ 45867.68973403],
#        [ 66427.89443988],
#        [ 62692.49004365],
#        [ 65368.05886653],
#        [ 59853.4523038 ],
#        [ 61975.50158878],
#        [ 64224.8158336 ],
#        [ 64224.8158336 ],
#        [ 65729.62251179],
#        [127099.02632771],
#        [108326.85259942],
#        [ 66976.88561573],
#        [ 69857.62353868],
#        [110391.55678236],
#        [ 61273.60385098],
#        [ 65368.05886653],
#        [ 90873.66176565],
#        [ 65512.79747138],
#        [ 60026.82838219],
#        [ 66511.30189947],
#        [102822.02246847],
#        [150017.02100552],
#        [ 65961.80403466],
#        [ 65368.05886653],
#        [ 63804.24976617],
#        [ 61059.50117952],
#        [ 61897.54555558],
#        [ 65368.05886653],
#        [ 61017.30794814],
# ...

# %%
y_test
# Out:
#       Price
# 196   50990
# 299   72990
# 171   41490
# 537  144690
# 551  129990
# ..      ...
# 368  114990
# 361  126000
# 446   57990
# 767  106990
# 529  110999
#
# [161 rows x 1 columns]

# %%
from sklearn.ensemble import RandomForestRegressor
rfg =RandomForestRegressor()

# %%
rfg.fit(x_train, y_train)
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\base.py:1336: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
lst=[[3,	32,	4,	4,	10966,	1185]]
rfg.predict(lst)
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([59991.48])

# %%
rfg.fit(x_train, y_train)
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\base.py:1336: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
x_test
# Out:
#      brand  os_bit  graphic_card_gb  rating  Number of Ratings  \
# 196      3      32                4       4              10966
# 299      1      32                0       4                 76
# 171      6      64                0       5                  7
# 537      5      64                6       4                 17
# 551      7      64                8       4                 14
# ..     ...     ...              ...     ...                ...
# 368      1      64                0       3                  0
# 361      5      64                0       5                  2
# 446      6      64                0       4                 47
# 767      2      64                4       3                  0
# 529      2      32                0       3                  0
#
#      Number of Reviews
# 196               1185
# 299                 14
# 171                  5
# 537                  4
# 551                  3
# ..                 ...
# 368                  0
# ...

# %%
pred =rfg.predict(x_test)

# %%
pred
# Out:
# array([ 60980.03      ,  56629.23      ,  65483.89      , 175110.15      ,
#        192020.        ,  76728.11636364,  91804.33333333,  70069.09747908,
#         64256.51      ,  87932.45026251,  58637.0655443 ,  51307.45      ,
#         81664.48573308,  81664.48573308,  62354.8       , 163993.46      ,
#         96995.18453175,  57870.3       ,  64996.38680773,  92551.84      ,
#         42705.        ,  87932.45026251,  79817.15333333,  66182.69      ,
#         44750.02      ,  62232.38074645,  73747.78      , 222791.57071429,
#         37376.57      ,  87932.45026251,  50593.23      ,  53941.3       ,
#         46147.32      ,  87932.45026251,  43864.47529582,  69977.6       ,
#        141655.53571429,  69191.57      ,  46424.07      ,  62915.496     ,
#         47051.44      ,  76074.72      ,  67306.5       ,  37173.5       ,
#        126189.88095238,  63033.7667381 ,  71113.58      ,  62232.38074645,
# ...

# %%
y_test
# Out:
#       Price
# 196   50990
# 299   72990
# 171   41490
# 537  144690
# 551  129990
# ..      ...
# 368  114990
# 361  126000
# 446   57990
# 767  106990
# 529  110999
#
# [161 rows x 1 columns]
